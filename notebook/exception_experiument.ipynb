# %%
print("all good")
import os   
import sys 

# Add parent directory to path so we can import from logger, exception, etc.
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)
# Out:
# all good

# %%
from logger.custom_logger import CustomLogger
logger = CustomLogger().get_logger("exception_experiment.log")

# %%
import sys 
import traceback 
class DocumentPortalException(Exception):
    """custome exception for document portal"""
    
    def __init__(self,error_message:str,error_details:sys):
       _,_,exe_tb = error_details.exc_info()
       self.file_name =exe_tb.tb_frame.f_code.co_filename
       self.line_number = exe_tb.tb_lineno
       self.error_message = str(error_message)
       self.traceback_str = ''.join(traceback.format_exception(*error_details.exc_info()))
    
    
    def __str__(self):
        return f"""
            Error in [{self.file_name}] at line number [{self.line_number}]
            Message : {self.error_message}
            Traceback : 
            {self.traceback_str}
        """
         

if __name__ == "__main__":
    try:
        a = 1/0
        print(a)
    except Exception as e:
        app_exc = DocumentPortalException(e,sys)
        logger.error(app_exc)
        raise app_exc
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[5], line 25
#      24 try:
# ---> 25     a = 1/0
#      26     print(a)
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 29
#      27 except Exception as e:
#      28     app_exc = DocumentPortalException(e,sys)
# ---> 29     logger.error(app_exc)
#      30     raise app_exc
#
# NameError: name 'logger' is not defined

# %%
# 1- information from exception can be logged into file , cloud config , command line ) ( it will keep the record of the error and will not stop the execution of the program)
# 2- rasie the exception it will stop the execution of the program

# %%
# Out:
# ['/Users/mahmoudmohamed/Library/Mobile Documents/com~apple~CloudDocs/Project/llmops_industry_ready_projects/document_portal',
#  '/Users/mahmoudmohamed/.local/share/uv/python/cpython-3.13.3-macos-aarch64-none/lib/python313.zip',
#  '/Users/mahmoudmohamed/.local/share/uv/python/cpython-3.13.3-macos-aarch64-none/lib/python3.13',
#  '/Users/mahmoudmohamed/.local/share/uv/python/cpython-3.13.3-macos-aarch64-none/lib/python3.13/lib-dynload',
#  '',
#  '/Users/mahmoudmohamed/Library/Mobile Documents/com~apple~CloudDocs/Project/llmops_industry_ready_projects/document_portal/.venv/lib/python3.13/site-packages']

# %%
import sys

# %%
_,_,exc_traceback = sys.exc_info()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 1/0
#       2 _,_,exc_traceback = sys.exc_info()
#
# ZeroDivisionError: division by zero

# %%
exc_traceback.tb_frame.f_code.co_filename
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 exc_traceback.tb_frame.f_code.co_filename
#
# AttributeError: 'NoneType' object has no attribute 'tb_frame'
